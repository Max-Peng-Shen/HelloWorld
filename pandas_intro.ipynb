# %%
import os
import pandas as pd
import numpy as np
import random

# %%
path1 = os.getcwd()
path2 = 'roster.csv'
csvFilePath = os.path.join(path1, path2)

# %% [markdown]
# ## Read CSV

# %%
roster = pd.read_csv(csvFilePath)
print(type(roster))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
roster.head()
# Out:
#         name
# 0        Joe
# 1     Jihuan
# 2        Ali
# 3    Frances
# 4  Daniela V

# %%
roster.tail()
# Out:
#         name
# 17  Hsin-Yun
# 18    Renata
# 19       Max
# 20    Joshua
# 21     David

# %%
roster
# Out:
#          name
# 0         Joe
# 1      Jihuan
# 2         Ali
# 3     Frances
# 4   Daniela V
# 5     Mostafa
# 6   Daniela P
# 7       Cesar
# 8      Jarrod
# 9      Austin
# 10       Jack
# 11        Ala
# 12     Sergii
# 13      Miles
# 14     Hyeyun
# 15  Volodymyr
# 16      Yijia
# 17   Hsin-Yun
# 18     Renata
# 19        Max
# 20     Joshua
# 21      David

# %% [markdown]
# ## Modifying the Data

# %%
d = {'name': ['Wally']}
tmp_df = pd.DataFrame(data=d)
roster = pd.concat([roster, tmp_df], ignore_index=True)
roster
# Out:
#          name
# 0         Joe
# 1      Jihuan
# 2         Ali
# 3     Frances
# 4   Daniela V
# 5     Mostafa
# 6   Daniela P
# 7       Cesar
# 8      Jarrod
# 9      Austin
# 10       Jack
# 11        Ala
# 12     Sergii
# 13      Miles
# 14     Hyeyun
# 15  Volodymyr
# 16      Yijia
# 17   Hsin-Yun
# 18     Renata
# 19        Max
# 20     Joshua
# 21      David
# 22      Wally

# %% [markdown]
# ## Asign Grades

# %%
np.random.seed(1)
grades = np.random.randint(0,100, size=len(roster))
print(grades)
# Out:
# [37 12 72  9 75  5 79 64 16  1 76 71  6 25 50 20 18 84 11 28 29 14 50]

# %%
roster['grade'] = np.random.randint(0,100, size=len(roster))
roster
# Out:
#          name  grade
# 0         Joe     68
# 1      Jihuan     87
# 2         Ali     87
# 3     Frances     94
# 4   Daniela V     96
# 5     Mostafa     86
# 6   Daniela P     13
# 7       Cesar      9
# 8      Jarrod      7
# 9      Austin     63
# 10       Jack     61
# 11        Ala     22
# 12     Sergii     57
# 13      Miles      1
# 14     Hyeyun      0
# 15  Volodymyr     60
# 16      Yijia     81
# 17   Hsin-Yun      8
# 18     Renata     88
# 19        Max     13
# 20     Joshua     47
# 21      David     72
# 22      Wally     30

# %% [markdown]
# ## Modify Specific row of data

# %% [markdown]
# .loc can be used with a boolean array (i.e. a an array of 1s and 0s)

# %%
roster.loc[roster.name == "Daniela P", "grade"] = 100
roster
# Out:
#          name  grade
# 0         Joe     68
# 1      Jihuan     87
# 2         Ali     87
# 3     Frances     94
# 4   Daniela V     96
# 5     Mostafa     86
# 6   Daniela P    100
# 7       Cesar      9
# 8      Jarrod      7
# 9      Austin     63
# 10       Jack     61
# 11        Ala     22
# 12     Sergii     57
# 13      Miles      1
# 14     Hyeyun      0
# 15  Volodymyr     60
# 16      Yijia     81
# 17   Hsin-Yun      8
# 18     Renata     88
# 19        Max     13
# 20     Joshua     47
# 21      David     72
# 22      Wally     30

# %% [markdown]
# # Check the Class Average

# %%
roster['grade'].mean()
# Out:
# 53.78260869565217

# %%
roster.loc[roster['grade'] < 69, 'grade'] = roster['grade'] + 30
roster['grade'].mean()
# Out:
# 72.04347826086956

# %% [markdown]
# # Write to CSV

# %%
outFilePath = os.path.join(os.getcwd(),'roster_pandas.csv')
print(outFilePath)
# Out:
# /Users/pengshen/HelloWorld/roster_pandas.csv

# %%
roster.to_csv(outFilePath, index = False)

# %% [markdown]
# ### More Aggregation and Manipulation

# %%
np.random.choice(['red','blue'], size = len(roster))
# Out:
# array(['blue', 'blue', 'red', 'blue', 'blue', 'blue', 'blue', 'red',
#        'red', 'blue', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue',
#        'blue', 'red', 'blue', 'red', 'red', 'blue'], dtype='<U4')

# %%
np.random.seed(1)
roster['group'] = np.random.choice(['red','blue'], size=len(roster))
roster
# Out:
#          name  grade group
# 0         Joe     98  blue
# 1      Jihuan     87  blue
# 2         Ali     87   red
# 3     Frances     94   red
# 4   Daniela V     96  blue
# 5     Mostafa     86  blue
# 6   Daniela P    100  blue
# 7       Cesar     39  blue
# 8      Jarrod     37  blue
# 9      Austin     93   red
# 10       Jack     91   red
# 11        Ala     52  blue
# 12     Sergii     87   red
# 13      Miles     31  blue
# 14     Hyeyun     30  blue
# 15  Volodymyr     90   red
# 16      Yijia     81   red
# 17   Hsin-Yun     38  blue
# 18     Renata     88   red
# 19        Max     43   red
# 20     Joshua     77   red
# 21      David     72  blue
# 22      Wally     60   red

# %%
group_means = roster.groupby(by=['group']).mean()
group_means
# Out:
#            grade
# group
# blue   63.833333
# red    81.000000

# %%
group_means.rename(columns={'grade':'group_avg'}, inplace = True)

# %%
group_means
# Out:
#        group_avg
# group
# blue   63.833333
# red    81.000000

# %% [markdown]
# # Merging DataFrames

# %%
print(roster.shape)
print(group_means.shape)
# Out:
# (23, 3)
# (2, 1)

# %%
roster = roster.merge(group_means, on=['group'])

# %% [markdown]
# roster.shape

# %%
roster
# Out:
#          name  grade group  group_avg
# 0         Joe     98  blue  63.833333
# 1      Jihuan     87  blue  63.833333
# 2   Daniela V     96  blue  63.833333
# 3     Mostafa     86  blue  63.833333
# 4   Daniela P    100  blue  63.833333
# 5       Cesar     39  blue  63.833333
# 6      Jarrod     37  blue  63.833333
# 7         Ala     52  blue  63.833333
# 8       Miles     31  blue  63.833333
# 9      Hyeyun     30  blue  63.833333
# 10   Hsin-Yun     38  blue  63.833333
# 11      David     72  blue  63.833333
# 12        Ali     87   red  81.000000
# 13    Frances     94   red  81.000000
# 14     Austin     93   red  81.000000
# 15       Jack     91   red  81.000000
# 16     Sergii     87   red  81.000000
# 17  Volodymyr     90   red  81.000000
# 18      Yijia     81   red  81.000000
# 19     Renata     88   red  81.000000
# 20        Max     43   red  81.000000
# 21     Joshua     77   red  81.000000
# 22      Wally     60   red  81.000000

# %% [markdown]
# ### Creating new columns from custom functions

# %%
def is_top50(col):
    return col > col.median()

# %%
roster['top50'] = roster[['grade']].apply(is_top50)

# %%
roster
# Out:
#          name  grade group  group_avg  top50
# 0         Joe     98  blue  63.833333   True
# 1      Jihuan     87  blue  63.833333   True
# 2   Daniela V     96  blue  63.833333   True
# 3     Mostafa     86  blue  63.833333  False
# 4   Daniela P    100  blue  63.833333   True
# 5       Cesar     39  blue  63.833333  False
# 6      Jarrod     37  blue  63.833333  False
# 7         Ala     52  blue  63.833333  False
# 8       Miles     31  blue  63.833333  False
# 9      Hyeyun     30  blue  63.833333  False
# 10   Hsin-Yun     38  blue  63.833333  False
# 11      David     72  blue  63.833333  False
# 12        Ali     87   red  81.000000   True
# 13    Frances     94   red  81.000000   True
# 14     Austin     93   red  81.000000   True
# 15       Jack     91   red  81.000000   True
# 16     Sergii     87   red  81.000000   True
# 17  Volodymyr     90   red  81.000000   True
# 18      Yijia     81   red  81.000000  False
# 19     Renata     88   red  81.000000   True
# 20        Max     43   red  81.000000  False
# 21     Joshua     77   red  81.000000  False
# 22      Wally     60   red  81.000000  False

# %%
roster['grade']
# Out:
# 0      98
# 1      87
# 2      96
# 3      86
# 4     100
# 5      39
# 6      37
# 7      52
# 8      31
# 9      30
# 10     38
# 11     72
# 12     87
# 13     94
# 14     93
# 15     91
# 16     87
# 17     90
# 18     81
# 19     88
# 20     43
# 21     77
# 22     60
# Name: grade, dtype: int64

# %%
roster[['grade']]
# Out:
#     grade
# 0      98
# 1      87
# 2      96
# 3      86
# 4     100
# 5      39
# 6      37
# 7      52
# 8      31
# 9      30
# 10     38
# 11     72
# 12     87
# 13     94
# 14     93
# 15     91
# 16     87
# 17     90
# 18     81
# 19     88
# 20     43
# 21     77
# 22     60

# %% [markdown]
# # Creating new columns from custom functions

# %%
roster['top50_group'] = roster.groupby(by=['group'])[['grade']].apply(is_top50)
roster
# Out:
#          name  grade group  group_avg  top50  top50_group
# 0         Joe     98  blue  63.833333   True         True
# 1      Jihuan     87  blue  63.833333   True         True
# 2   Daniela V     96  blue  63.833333   True         True
# 3     Mostafa     86  blue  63.833333  False         True
# 4   Daniela P    100  blue  63.833333   True         True
# 5       Cesar     39  blue  63.833333  False        False
# 6      Jarrod     37  blue  63.833333  False        False
# 7         Ala     52  blue  63.833333  False        False
# 8       Miles     31  blue  63.833333  False        False
# 9      Hyeyun     30  blue  63.833333  False        False
# 10   Hsin-Yun     38  blue  63.833333  False        False
# 11      David     72  blue  63.833333  False         True
# 12        Ali     87   red  81.000000   True        False
# 13    Frances     94   red  81.000000   True         True
# 14     Austin     93   red  81.000000   True         True
# 15       Jack     91   red  81.000000   True         True
# 16     Sergii     87   red  81.000000   True        False
# 17  Volodymyr     90   red  81.000000   True         True
# 18      Yijia     81   red  81.000000  False        False
# 19     Renata     88   red  81.000000   True         True
# 20        Max     43   red  81.000000  False        False
# 21     Joshua     77   red  81.000000  False        False
# 22      Wally     60   red  81.000000  False        False

# %% [markdown]
# ## Apply

# %% [markdown]
# # pandas.Series.apply

# %%
grade_series = roster['grade']
print(type(grade_series))
grade_series
# Out:
# <class 'pandas.core.series.Series'>
# 0      98
# 1      87
# 2      96
# 3      86
# 4     100
# 5      39
# 6      37
# 7      52
# 8      31
# 9      30
# 10     38
# 11     72
# 12     87
# 13     94
# 14     93
# 15     91
# 16     87
# 17     90
# 18     81
# 19     88
# 20     43
# 21     77
# 22     60
# Name: grade, dtype: int64

# %%
def print_arg(x):
    print(x)

def print_type(x):
    print(type(x))

# %%
grade_series.apply(print_arg)
# Out:
# 98
# 87
# 96
# 86
# 100
# 39
# 37
# 52
# 31
# 30
# 38
# 72
# 87
# 94
# 93
# 91
# 87
# 90
# 81
# 88
# 43
# 77
# 60
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# Name: grade, dtype: object

# %% [markdown]
# # pandas.DataFrame.apply

# %%
grade_df = roster[['grade']]
print(type(grade_df))
grade_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     grade
# 0      98
# 1      87
# 2      96
# 3      86
# 4     100
# 5      39
# 6      37
# 7      52
# 8      31
# 9      30
# 10     38
# 11     72
# 12     87
# 13     94
# 14     93
# 15     91
# 16     87
# 17     90
# 18     81
# 19     88
# 20     43
# 21     77
# 22     60

# %%
grade_df.apply(print_type, axis=0)
# Out:
# <class 'pandas.core.series.Series'>
# grade    None
# dtype: object

# %%
grade_df.apply(print_arg, axis=1)
# Out:
# grade    98
# Name: 0, dtype: int64
# grade    87
# Name: 1, dtype: int64
# grade    96
# Name: 2, dtype: int64
# grade    86
# Name: 3, dtype: int64
# grade    100
# Name: 4, dtype: int64
# grade    39
# Name: 5, dtype: int64
# grade    37
# Name: 6, dtype: int64
# grade    52
# Name: 7, dtype: int64
# grade    31
# Name: 8, dtype: int64
# grade    30
# Name: 9, dtype: int64
# grade    38
# Name: 10, dtype: int64
# grade    72
# Name: 11, dtype: int64
# grade    87
# Name: 12, dtype: int64
# grade    94
# Name: 13, dtype: int64
# grade    93
# Name: 14, dtype: int64
# grade    91
# Name: 15, dtype: int64
# grade    87
# Name: 16, dtype: int64
# grade    90
# Name: 17, dtype: int64
# grade    81
# Name: 18, dtype: int64
# grade    88
# Name: 19, dtype: int64
# grade    43
# Name: 20, dtype: int64
# grade    77
# Name: 21, dtype: int64
# grade    60
# Name: 22, dtype: int64
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# dtype: object

# %% [markdown]
# # DataFrameGroupBy

# %%
groups = roster.groupby(by=['group'])
print(type(groups))
groups
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
groups.apply(print_arg)
# Out:
#          name  grade group  group_avg  top50  top50_group
# 0         Joe     98  blue  63.833333   True         True
# 1      Jihuan     87  blue  63.833333   True         True
# 2   Daniela V     96  blue  63.833333   True         True
# 3     Mostafa     86  blue  63.833333  False         True
# 4   Daniela P    100  blue  63.833333   True         True
# 5       Cesar     39  blue  63.833333  False        False
# 6      Jarrod     37  blue  63.833333  False        False
# 7         Ala     52  blue  63.833333  False        False
# 8       Miles     31  blue  63.833333  False        False
# 9      Hyeyun     30  blue  63.833333  False        False
# 10   Hsin-Yun     38  blue  63.833333  False        False
# 11      David     72  blue  63.833333  False         True
#          name  grade group  group_avg  top50  top50_group
# 12        Ali     87   red       81.0   True        False
# 13    Frances     94   red       81.0   True         True
# 14     Austin     93   red       81.0   True         True
# 15       Jack     91   red       81.0   True         True
# 16     Sergii     87   red       81.0   True        False
# 17  Volodymyr     90   red       81.0   True         True
# 18      Yijia     81   red       81.0  False        False
# 19     Renata     88   red       81.0   True         True
# 20        Max     43   red       81.0  False        False
# 21     Joshua     77   red       81.0  False        False
# 22      Wally     60   red       81.0  False        False
# Empty DataFrame
# Columns: []
# Index: []

# %%
groups.apply(print_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: []

# %%
groups1 = roster.groupby('group')
print(type(groups1))
groups1
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
groups1.apply(print_arg)
# Out:
#          name  grade group  group_avg  top50  top50_group
# 0         Joe     98  blue  63.833333   True         True
# 1      Jihuan     87  blue  63.833333   True         True
# 2   Daniela V     96  blue  63.833333   True         True
# 3     Mostafa     86  blue  63.833333  False         True
# 4   Daniela P    100  blue  63.833333   True         True
# 5       Cesar     39  blue  63.833333  False        False
# 6      Jarrod     37  blue  63.833333  False        False
# 7         Ala     52  blue  63.833333  False        False
# 8       Miles     31  blue  63.833333  False        False
# 9      Hyeyun     30  blue  63.833333  False        False
# 10   Hsin-Yun     38  blue  63.833333  False        False
# 11      David     72  blue  63.833333  False         True
#          name  grade group  group_avg  top50  top50_group
# 12        Ali     87   red       81.0   True        False
# 13    Frances     94   red       81.0   True         True
# 14     Austin     93   red       81.0   True         True
# 15       Jack     91   red       81.0   True         True
# 16     Sergii     87   red       81.0   True        False
# 17  Volodymyr     90   red       81.0   True         True
# 18      Yijia     81   red       81.0  False        False
# 19     Renata     88   red       81.0   True         True
# 20        Max     43   red       81.0  False        False
# 21     Joshua     77   red       81.0  False        False
# 22      Wally     60   red       81.0  False        False
# Empty DataFrame
# Columns: []
# Index: []

# %%
groups1.apply(print_type)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: []
